# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
dis15, fes15 = np.loadtxt('1d-wham/free_energy15',comments=['@', '#'], unpack=True)
dis20, fes20 = np.loadtxt('1d-wham/free_energy20',comments=['@', '#'], unpack=True)
dis25, fes25 = np.loadtxt('1d-wham/free_energy25',comments=['@', '#'], unpack=True)
dis30, fes30 = np.loadtxt('1d-wham/free_energy30',comments=['@', '#'], unpack=True)
dis35, fes35 = np.loadtxt('1d-wham/free_energy35',comments=['@', '#'], unpack=True)
dis40, fes40 = np.loadtxt('1d-wham/free_energy40',comments=['@', '#'], unpack=True)
dis45, fes45 = np.loadtxt('1d-wham/free_energy45',comments=['@', '#'], unpack=True)
dis50, fes50 = np.loadtxt('1d-wham/free_energy50',comments=['@', '#'], unpack=True)
dis55, fes55 = np.loadtxt('1d-wham/free_energy55',comments=['@', '#'], unpack=True)
dis60, fes60 = np.loadtxt('1d-wham/free_energy60',comments=['@', '#'], unpack=True)
dis65, fes65 = np.loadtxt('1d-wham/free_energy65',comments=['@', '#'], unpack=True)
dis70, fes70 = np.loadtxt('1d-wham/free_energy70',comments=['@', '#'], unpack=True)
dis75, fes75 = np.loadtxt('1d-wham/free_energy75',comments=['@', '#'], unpack=True)
dis80, fes80 = np.loadtxt('1d-wham/free_energy80',comments=['@', '#'], unpack=True)
dis85, fes85 = np.loadtxt('1d-wham/free_energy85',comments=['@', '#'], unpack=True)
dis90, fes90 = np.loadtxt('1d-wham/free_energy90',comments=['@', '#'], unpack=True)
dis95, fes95 = np.loadtxt('1d-wham/free_energy95',comments=['@', '#'], unpack=True)
dis100, fes100 = np.loadtxt('1d-wham/free_energy100',comments=['@', '#'], unpack=True)



time, error = np.loadtxt('1d-wham/L2-error.dat',comments=['@', '#'], unpack=True)

# %%
min(fes100)
# Out:
# -6.9529293

# %%
### plt.rc('font', family='Helvetica')
cm = 1/2.54  # centimeters in inches


#plt.figure(figsize=[3.5,2.7])   #Plot Size
#To create three suplots
fig, (ax1, ax2, ax3) = plt.subplots(3,1, figsize=(9*cm,21*cm))
fig.subplots_adjust(hspace=0.3, wspace=0.0)

#linewidth, alpha for occupancy of line color 
# ax1.plot(dis15*10, fes15+11.150066, '-r', label="15", linewidth=1.0, alpha=0.8)        #Line plot
#ax1.plot(dis15*10, fes20+10.877666, '-g', label='20', linewidth=1.0, alpha=0.8)        #Line plot
#ax1.plot(dis15*10, fes25+9.3080599, '-b', label='25', linewidth=1.0, alpha=0.8)        #Line plot
#ax1.plot(dis15*10, fes30+8.3866883, '-r', label='30', linewidth=1.0, alpha=0.8)        #Line plot
#ax1.plot(dis15*10, fes35+8.2419524, '-r', label='35', linewidth=1.0, alpha=0.8)        #Line plot
#ax1.plot(dis15*10, fes40+8.6875754, '-g', label='40', linewidth=1.0, alpha=0.8)        #Line plot
#ax1.plot(dis15*10, fes45+8.2388583, '-y', label='45', linewidth=1.0, alpha=0.8)        #Line plot
ax2.plot(dis15*10, fes50+7.8800278, '-m', label='50 ns/window', linewidth=1.0, alpha=0.5)        #Line plot
#ax1.plot(dis15*10, fes55+7.8943382, '-m', label='55', linewidth=1.0, alpha=0.8)        #Line plot
ax2.plot(dis15*10, fes60+7.6185175, '-g', label='60 ns/window', linewidth=1.0, alpha=0.5)        #Line plot
#ax1.plot(dis15*10, fes65+7.3451033, '-g', label='65', linewidth=1.0, alpha=0.5)        #Line plot
ax2.plot(dis15*10, fes70+7.3301115, '-r', label='70 ns/window', linewidth=1.0, alpha=0.5)        #Lin*10e plot
ax2.plot(dis15*10, fes75+7.4709708, '-k', label='75 ns/window', linewidth=1.0, alpha=1.0)        #Line plot
#ax1.plot(dis15*10, fes80+7.6153522, '-b', label='80', linewidth=1.0, alpha=0.3)        #Line plot
# ax1.plot(dis15*10, fes85+7.8257125, '-r', label='85', linewidth=1.0, alpha=0.2)        #Line plot
# ax1.plot(dis15*10, fes90+7.438083, '-g', label='90', linewidth=1.0, alpha=0.2)        #Line plot
# ax1.plot(dis15*10, fes95+7.1840634, '-r', label='95', linewidth=1.0, alpha=0.1)        #Line plot
# ax1.plot(dis15*10, fes100+6.9529293, '-m', label='100', linewidth=1.0, alpha=0.1)        #Line plot

ax2.legend(loc='upper right', bbox_to_anchor=(0.95, 1.1), labelcolor='linecolor', handlelength=0, labelspacing=0.1, frameon=False)


ax2.plot(dis15, fes15, '-g', label='B1', linewidth=1.0, alpha=0.8)        #Line plot


ax3.plot(time, error, 'b', marker='D', label='B2', linewidth=1.0, alpha=0.8)        #Line ********1010101010101010pl*10ot


ax1.set_ylabel('${\Delta}$${F}$ (kcal/mol)', fontsize=15)   
#ax1.set_ylabel('angle (${\theta}{\mathrm_{H}}$)', fontsize=16)                     #ylabel
ax2.set_ylabel('${\Delta}$${F}$ (kcal/mol)', fontsize=15)   
ax3.set_ylabel('$L$$^{2}$ error (kcal/mol)', fontsize=15)                             #ylabel

#ax1.set_xlabel('Dis (${\mathrm{\AA}}$)', fontsize=15)           #xlabel
ax2.set_xlabel('Dis (${\mathrm{\AA}}$)', fontsize=15)           #xlabel
ax3.set_xlabel('time (ns/window)', fontsize=15)           #xlabel

ax1.set_xlim(7, 21)                                  #xrange
ax2.set_xlim(7, 21)                                  #xrange
ax3.set_xlim(20, 75)                                  #xrange

ax1.set_ylim(0, 10)                                      #yrange
ax2.set_ylim(0, 10)                                      #yrange
ax3.set_ylim(0, 3)                                      #yrange

ax1.set_xticks(np.arange(8, 22, 2 ), fontsize=14)         #ticks
ax1.set_yticks(np.arange(0, 10, 1), fontsize=14)
ax1.text(3.4, 10, 'A', fontsize=18, weight='bold')
#ax1.text(120, 30, 'inward', fontsize=16)

ax2.set_xticks(np.arange(8, 22, 2 ), fontsize=14)         #ticks
ax2.set_yticks(np.arange(0, 10, 1), fontsize=14)
ax2.text(3.4, 10, 'B', fontsize=18, weight='bold')

#ax2.text(-60, 8, 'B', fontsize=18, weight='bold')

ax3.set_xticks(np.arange(20, 76, 10 ), fontsize=14)         #ticks
ax3.set_yticks(np.arange(0, 3.05, 1), fontsize=14)
ax3.text(6, 3,  'C', fontsize=18, weight='bold')

from matplotlib.ticker import MultipleLocator
ax1.xaxis.set_minor_locator(MultipleLocator(1))
ax2.xaxis.set_minor_locator(MultipleLocator(1))
ax3.xaxis.set_minor_locator(MultipleLocator(5))
ax3.yaxis.set_minor_locator(MultipleLocator(0.5))


#To hide the top and right axis of the plot
#ax=ax1.gca()
# Hide the right and top spines
ax1.spines['right'].set_visible(False)
ax1.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax3.spines['right'].set_visible(False)
ax3.spines['top'].set_visible(False)

# Only show ticks on the left and bottom spines
ax1.yaxis.set_ticks_position('left')
ax1.xaxis.set_ticks_position('bottom')
ax2.yaxis.set_ticks_position('left')
ax2.xaxis.set_ticks_position('bottom')
ax3.yaxis.set_ticks_position('left')
ax3.xaxis.set_ticks_position('bottom')

#to remove whitespace, and set dpi
fig.savefig('figure-fes.pdf', dpi = 300, bbox_inches='tight', pad_inches = 0) 
#plt.show()
